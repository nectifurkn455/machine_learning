# %%
import pandas as pd

# %%
#Exercise8
College = pd.read_csv('/home/necati/machine_learning/ISLP/Datasets/College.csv')

# %%
College
# Out:
#                          Unnamed: 0 Private   Apps  Accept  Enroll  Top10perc  \
# 0      Abilene Christian University     Yes   1660    1232     721         23
# 1                Adelphi University     Yes   2186    1924     512         16
# 2                    Adrian College     Yes   1428    1097     336         22
# 3               Agnes Scott College     Yes    417     349     137         60
# 4         Alaska Pacific University     Yes    193     146      55         16
# ..                              ...     ...    ...     ...     ...        ...
# 772         Worcester State College      No   2197    1515     543          4
# 773               Xavier University     Yes   1959    1805     695         24
# 774  Xavier University of Louisiana     Yes   2097    1915     695         34
# 775                 Yale University     Yes  10705    2453    1317         95
# 776    York College of Pennsylvania     Yes   2989    1855     691         28
#
# ...

# %%
College[College['Private'] == 'No'].shape
# Out:
# (212, 19)

# %%
college2 = pd.read_csv('/home/necati/machine_learning/ISLP/Datasets/College.csv', index_col=0)
college2
# Out:
#                                Private   Apps  Accept  Enroll  Top10perc  \
# Abilene Christian University       Yes   1660    1232     721         23
# Adelphi University                 Yes   2186    1924     512         16
# Adrian College                     Yes   1428    1097     336         22
# Agnes Scott College                Yes    417     349     137         60
# Alaska Pacific University          Yes    193     146      55         16
# ...                                ...    ...     ...     ...        ...
# Worcester State College             No   2197    1515     543          4
# Xavier University                  Yes   1959    1805     695         24
# Xavier University of Louisiana     Yes   2097    1915     695         34
# Yale University                    Yes  10705    2453    1317         95
# York College of Pennsylvania       Yes   2989    1855     691         28
#
#                                 Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# ...

# %%
college3 = College.rename({'Unnamed: 0': 'College'},axis=1)
college3
# Out:
#                             College Private   Apps  Accept  Enroll  Top10perc  \
# 0      Abilene Christian University     Yes   1660    1232     721         23
# 1                Adelphi University     Yes   2186    1924     512         16
# 2                    Adrian College     Yes   1428    1097     336         22
# 3               Agnes Scott College     Yes    417     349     137         60
# 4         Alaska Pacific University     Yes    193     146      55         16
# ..                              ...     ...    ...     ...     ...        ...
# 772         Worcester State College      No   2197    1515     543          4
# 773               Xavier University     Yes   1959    1805     695         24
# 774  Xavier University of Louisiana     Yes   2097    1915     695         34
# 775                 Yale University     Yes  10705    2453    1317         95
# 776    York College of Pennsylvania     Yes   2989    1855     691         28
#
# ...

# %%
college3.set_index('College')
# Out:
#                                Private   Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University       Yes   1660    1232     721         23
# Adelphi University                 Yes   2186    1924     512         16
# Adrian College                     Yes   1428    1097     336         22
# Agnes Scott College                Yes    417     349     137         60
# Alaska Pacific University          Yes    193     146      55         16
# ...                                ...    ...     ...     ...        ...
# Worcester State College             No   2197    1515     543          4
# Xavier University                  Yes   1959    1805     695         24
# Xavier University of Louisiana     Yes   2097    1915     695         34
# Yale University                    Yes  10705    2453    1317         95
# York College of Pennsylvania       Yes   2989    1855     691         28
#
#                                 Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# ...

# %%
College = college3

# %%
College.columns
# Out:
# Index(['College', 'Private', 'Apps', 'Accept', 'Enroll', 'Top10perc',
#        'Top25perc', 'F.Undergrad', 'P.Undergrad', 'Outstate', 'Room.Board',
#        'Books', 'Personal', 'PhD', 'Terminal', 'S.F.Ratio', 'perc.alumni',
#        'Expend', 'Grad.Rate'],
#       dtype='object')

# %%
College.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %%
pd.plotting.scatter_matrix(College[['Top10perc', 'Apps', 'Enroll']])
# Out:
# array([[<AxesSubplot:xlabel='Top10perc', ylabel='Top10perc'>,
#         <AxesSubplot:xlabel='Apps', ylabel='Top10perc'>,
#         <AxesSubplot:xlabel='Enroll', ylabel='Top10perc'>],
#        [<AxesSubplot:xlabel='Top10perc', ylabel='Apps'>,
#         <AxesSubplot:xlabel='Apps', ylabel='Apps'>,
#         <AxesSubplot:xlabel='Enroll', ylabel='Apps'>],
#        [<AxesSubplot:xlabel='Top10perc', ylabel='Enroll'>,
#         <AxesSubplot:xlabel='Apps', ylabel='Enroll'>,
#         <AxesSubplot:xlabel='Enroll', ylabel='Enroll'>]], dtype=object)

# %%
'Private' in College.columns
# Out:
# True

# %%
College[['Outstate', 'Private']].head()
# Out:
#    Outstate Private
# 0      7440     Yes
# 1     12280     Yes
# 2     11250     Yes
# 3     12960     Yes
# 4      7560     Yes

# %%
College['Private'] = College['Private'].map({'Yes': 1, 'No':0})

# %%
College.head()
# Out:
#                         College  Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University        1  1660    1232     721         23
# 1            Adelphi University        1  2186    1924     512         16
# 2                Adrian College        1  1428    1097     336         22
# 3           Agnes Scott College        1   417     349     137         60
# 4     Alaska Pacific University        1   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
# ...

# %%
College.boxplot(column=['Outstate', 'Private'])
# Out:
# <AxesSubplot:>

# %%
College['Elite'] = pd.cut(College['Top10perc'], [0,50,100], labels=['No', 'Yes'])
College[['College','Elite']]
# Out:
#                             College Elite
# 0      Abilene Christian University    No
# 1                Adelphi University    No
# 2                    Adrian College    No
# 3               Agnes Scott College   Yes
# 4         Alaska Pacific University    No
# ..                              ...   ...
# 772         Worcester State College    No
# 773               Xavier University    No
# 774  Xavier University of Louisiana    No
# 775                 Yale University   Yes
# 776    York College of Pennsylvania    No
#
# [777 rows x 2 columns]

# %%
College['Elite'].value_counts()
# Out:
# Elite
# No     699
# Yes     78
# Name: count, dtype: int64

# %%
College['Apps'].plot.hist(bins=8)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#Exercise 9
import numpy as np
import pandas as pd
Auto = pd.read_csv('/home/necati/machine_learning/ISLP/Datasets/Auto.csv', na_values=['?'])

# %%
Auto.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'year', 'origin', 'name'],
#       dtype='object')

# %%
np.max(Auto['horsepower']), np.min(Auto['horsepower'])
# Out:
# (230.0, 46.0)

# %%
for i in Auto['horsepower']:
    if i > 200:
        print(i)
# Out:
# 220.0
# 215.0
# 225.0
# 225.0
# 215.0
# 210.0
# 208.0
# 215.0
# 225.0
# 230.0

# %%
Auto.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0       130.0    3504          12.0    70
# 1  15.0          8         350.0       165.0    3693          11.5    70
# 2  18.0          8         318.0       150.0    3436          11.0    70
# 3  16.0          8         304.0       150.0    3433          12.0    70
# 4  17.0          8         302.0       140.0    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
Auto[Auto['horsepower'] > 200]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 6    14.0          8         454.0       220.0    4354           9.0    70
# 7    14.0          8         440.0       215.0    4312           8.5    70
# 8    14.0          8         455.0       225.0    4425          10.0    70
# 13   14.0          8         455.0       225.0    3086          10.0    70
# 25   10.0          8         360.0       215.0    4615          14.0    70
# 27   11.0          8         318.0       210.0    4382          13.5    70
# 67   11.0          8         429.0       208.0    4633          11.0    72
# 94   13.0          8         440.0       215.0    4735          11.0    73
# 95   12.0          8         455.0       225.0    4951          11.0    73
# 116  16.0          8         400.0       230.0    4278           9.5    73
#
#      origin                          name
# 6         1              chevrolet impala
# 7         1             plymouth fury iii
# ...

# %%
np.mean(Auto['horsepower']), np.std(Auto['horsepower'])
# Out:
# (104.46938775510205, 38.44203271442593)

# %%
droppedAuto = Auto.drop(index=range(10,85))
droppedAuto.iloc[range(8,26)]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 8    14.0          8         455.0       225.0    4425          10.0    70
# 9    15.0          8         390.0       190.0    3850           8.5    70
# 85   13.0          8         350.0       175.0    4100          13.0    73
# 86   14.0          8         304.0       150.0    3672          11.5    73
# 87   13.0          8         350.0       145.0    3988          13.0    73
# 88   14.0          8         302.0       137.0    4042          14.5    73
# 89   15.0          8         318.0       150.0    3777          12.5    73
# 90   12.0          8         429.0       198.0    4952          11.5    73
# 91   13.0          8         400.0       150.0    4464          12.0    73
# 92   13.0          8         351.0       158.0    4363          13.0    73
# 93   14.0          8         318.0       150.0    4237          14.5    73
# ...

# %%
np.mean(droppedAuto['horsepower']), np.std(droppedAuto['horsepower'])
# Out:
# (101.23584905660377, 36.12814854598646)

# %%
Auto.iloc[[126]]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 126  21.0          6         200.0         NaN    2875          17.0    74
#
#      origin           name
# 126       1  ford maverick

# %%
Auto[Auto['name']== 'ford pinto']
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 32   25.0          4          98.0         NaN    2046          19.0    71
# 112  19.0          4         122.0        85.0    2310          18.5    73
# 130  26.0          4         122.0        80.0    2451          16.5    74
# 168  23.0          4         140.0        83.0    2639          17.0    75
# 174  18.0          6         171.0        97.0    2984          14.5    75
# 206  26.5          4         140.0        72.0    2565          13.6    76
#
#      origin        name
# 32        1  ford pinto
# 112       1  ford pinto
# 130       1  ford pinto
# 168       1  ford pinto
# 174       1  ford pinto
# 206       1  ford pinto

# %%
import matplotlib.pyplot as plt

# %%
AutoforGraph = Auto.dropna(subset=['horsepower', 'mpg'])

# %%
plt.scatter(Auto['horsepower'], Auto['mpg'], color='blue', alpha=0.2)
plt.xlabel('horsepower')
plt.ylabel('miles per gallon')
plt.title('Relationship between horsepower and mpg')
# Out:
# Text(0.5, 1.0, 'Relationship between horsepower and mpg')
